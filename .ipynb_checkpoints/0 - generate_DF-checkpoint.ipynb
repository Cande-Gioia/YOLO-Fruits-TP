# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
from pathlib import Path
from detection_helper import create_DF
from matplotlib import pyplot as plt
import numpy as np

# %%
train_files = list(Path("Dataset/train/").glob("**/*txt"))
val_files = list(Path("Dataset/validation/").glob("**/*txt"))

# %%
df_train = create_DF(train_files,Path("Dataset/train/Apple_Grape_Cantaloupe_Watermelon_Pomegranate_Pineapple_Peach_Mango_Banana_Lemon_Tomato_Strawberry_Pear/"))

# %%
df_val = create_DF(val_files,Path("Dataset/validation/Apple_Grape_Cantaloupe_Watermelon_Pomegranate_Pineapple_Peach_Mango_Banana_Lemon_Tomato_Strawberry_Pear/"))

# %%
df_train.head()
# Out:
#         label    left         top   right      bottom  height  width  \
# 0       Apple  236.16    0.000000  625.92  342.140654    1024    683
# 1       Apple  318.72   44.209224  466.56  246.674329    1024    683
# 2       Grape  285.44  390.194485  469.12  565.749390    1024    683
# 3  Strawberry  321.28  484.231821  493.44  654.609170    1024    841
# 4  Strawberry  111.36  332.428798  187.52  450.924857    1024    841
#
#                                                image        image_name  \
# 0  Dataset/train/Apple_Grape_Cantaloupe_Watermelo...  837bf3be7055dc46
# 1  Dataset/train/Apple_Grape_Cantaloupe_Watermelo...  837bf3be7055dc46
# 2  Dataset/train/Apple_Grape_Cantaloupe_Watermelo...  116b98c8f1a2538c
# 3  Dataset/train/Apple_Grape_Cantaloupe_Watermelo...  b1e2809b606fb594
# 4  Dataset/train/Apple_Grape_Cantaloupe_Watermelo...  b1e2809b606fb594
#
#    center_x    center_y  delta_x     delta_y
# 0    431.04  171.070327   389.76  342.140654
# 1    392.64  145.441777   147.84  202.465105
# 2    377.28  477.971938   183.68  175.554905
# 3    407.36  569.420496   172.16  170.377349
# 4    149.44  391.676828    76.16  118.496059

# %%
df_val.head()
# Out:
#         label        left         top        right       bottom  height  \
# 0      Tomato   72.387584  119.736162   793.486336   619.030503    1024
# 1       Lemon   89.567232  152.054784   441.594880   461.195520    1024
# 2  Strawberry    0.000000    0.053248  1023.358976  1024.000000    1024
# 3       Lemon  236.441600   90.215200   905.010176   573.973625    1024
# 4       Lemon  320.348160   30.697525   724.350976   119.152075    1024
#
#    width                                              image        image_name  \
# 0    819  Dataset/validation/Apple_Grape_Cantaloupe_Wate...  604835415b761f30
# 1    768  Dataset/validation/Apple_Grape_Cantaloupe_Wate...  b39532c4a3bd5d83
# 2   1024  Dataset/validation/Apple_Grape_Cantaloupe_Wate...  e0be14f0681f4b39
# 3    575  Dataset/validation/Apple_Grape_Cantaloupe_Wate...  730020d358ea3d82
# 4    575  Dataset/validation/Apple_Grape_Cantaloupe_Wate...  730020d358ea3d82
#
#      center_x    center_y      delta_x      delta_y
# 0  432.936960  369.383333   721.098752   499.294341
# 1  265.581056  306.625152   352.027648   309.140736
# 2  511.679488  512.026624  1023.358976  1023.946752
# 3  570.725888  332.094412   668.568576   483.758425
# 4  522.349568   74.924800   404.002816    88.454550

# %%
classes = df_train["label"].unique()
classes
# Out:
# array(['Apple', 'Grape', 'Strawberry', 'Banana', 'Lemon', 'Pomegranate',
#        'Mango', 'Peach', 'Tomato', 'Pear', 'Watermelon', 'Pineapple',
#        'Cantaloupe'], dtype=object)

# %%
classes_idx = {clase:idx for idx,clase in enumerate(classes)}

# %%
cant_classes = len(classes)
cant_classes
# Out:
# 13

# %%
import pickle
with open("data.pkl","wb") as f:
    pickle.dump((df_train, df_val, train_files, val_files, classes_idx, cant_classes, classes),f)

# %% [markdown]
# # Vamos a entrenar con imágenes de 512 x 512

# %% [markdown]
# # Pruebas con Albumentations

# %%
import albumentations as A
from PIL import Image
import matplotlib.patches as patches

# %%
transform = A.Compose([
    A.RandomCrop(width=512, height=512),
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.2),
], bbox_params=A.BboxParams(format='coco', min_area=1024, min_visibility=0.1))

# %%
df_train.loc[0]
# Out:
# label                                                     Apple
# left                                                     236.16
# top                                                           0
# right                                                    625.92
# bottom                                                  342.141
# height                                                     1024
# width                                                       683
# image         Dataset/train/Apple_Grape_Cantaloupe_Watermelo...
# image_name                                     837bf3be7055dc46
# center_x                                                 431.04
# center_y                                                 171.07
# delta_x                                                  389.76
# delta_y                                                 342.141
# Name: 0, dtype: object

# %%
img_nbr=140
image_name = train_files[img_nbr].stem
image_file = df_train[df_train["image_name"] == image_name]["image"]

# %%
image_name
# Out:
# '6951f99fae687ec8'

# %%
image = np.array(Image.open(image_file.values[0]))
bboxes = df_train[df_train["image"]==image_file.values[0]][["left","top","delta_x","delta_y","label"]]

# %%
bboxes.values
# Out:
# array([[309.76, 347.9072230000001, 360.32000000000005, 278.0691070000001,
#         'Tomato'],
#        [288.64, 94.185017, 529.92, 415.18204000000003, 'Tomato']],
#       dtype=object)

# %%
transformed = transform(image=image, bboxes=bboxes.values)
# Create figure and axes
fig,ax = plt.subplots(1, figsize=[12,12])
plt.imshow(transformed["image"])
for bbox in transformed["bboxes"]:
    rect = patches.Rectangle((bbox[0],bbox[1]),bbox[2],bbox[3],linewidth=1,edgecolor='r',facecolor='none')
    # Add the patch to the Axes
    ax.add_patch(rect)
    plt.text(bbox[0],bbox[1],bbox[4], c="w")
plt.show()

# %%
bboxes_aug = transformed["bboxes"]
image_aug = transformed["image"]

# %% [markdown]
# # En qué gridcell anoto cada bbox?
#
# supongamos gridcells de 32x32

# %%
def get_gridcell(bboxes,grid_size):
    print( [((bbox[0] + bbox[2]/2), 
             (bbox[1] + bbox[3]/2)) for bbox in bboxes_aug])
    grid_cells = [((bbox[0] + bbox[2]/2)//grid_size[0], 
                   (bbox[1] + bbox[3]/2)//grid_size[1]) for bbox in bboxes_aug]
    return grid_cells

# %%
bboxes_aug
# Out:
# [(0.0, 339.90722300000016, 288.24, 172.09277699999984, 'Tomato'),
#  (0.0, 86.185017, 309.36, 415.18204000000003, 'Tomato')]

# %%
get_gridcell(bboxes_aug,[32,32])
# Out:
# [(144.12, 425.9536115000001), (154.68, 293.77603700000003)]
# [(4.0, 13.0), (4.0, 9.0)]

# %%
def get_gridcell(bboxes,grid_size):
    grid_cells = [(int((bbox[0] + bbox[2]/2)//grid_size[0]), 
                   int((bbox[1] + bbox[3]/2)//grid_size[1])) for bbox in bboxes_aug]
    return grid_cells

# %%
grid_cells = get_gridcell(bboxes_aug,[32,32])
grid_cells_u = np.unique(get_gridcell(bboxes_aug,[32,32]),axis=1)

# %% [markdown]
# # Chequeo de IoU con anchor boxes

# %%
def anchor_check(anchor_boxes, bbox):
    aux_bbox = np.array(bbox[:-1]).reshape(-1,4).repeat(len(anchor_boxes),axis=0)
    intersects = np.min([anchor_boxes[:,0],aux_bbox[:,2]],axis=0)*np.min([anchor_boxes[:,1],aux_bbox[:,3]],axis=0)
    union = aux_bbox[:,2]*aux_bbox[:,3]+anchor_boxes[:,0]*anchor_boxes[:,1]-intersects
    return intersects/union

# %%
IoU_alpha = 0.5

# %%
annotations = list()
for cell_u in grid_cells_u:
    indexes = [cell_u.tolist() == list(grid_cell) for grid_cell in grid_cells]
    bboxes_cell = [bboxes_aug[idx] for idx,index in enumerate(indexes) if index]
    winners = np.zeros([len(bboxes_cell),len(anchor_boxes)])
    for idx,bbox in enumerate(bboxes_cell):
        winners[idx,:] = anchor_check(anchor_boxes,bbox)
    mask = winners.max(axis=0) > IoU_alpha
    bbox_nbr = winners.argmax(axis=0)
    for ab,(m,b) in enumerate(zip(mask,bbox_nbr)):
        if m:
            annotations.append((cell_u, ab, bboxes_cell[b]))

# %% [markdown]
# # Armo la anotación para esta imagen

# %%
ann_size = 1 + cant_classes + 4
y = np.zeros([1,int(512/32),int(512/32),len(anchor_boxes)*ann_size])

# %%
y.shape
# Out:
# (1, 16, 16, 288)

# %%
def coco_to_yolo(ann):

# %%
# grid_cell, anchor_box, bbox
for ann in annotations:
    y[0,ann[0][1],ann[0][0], ann[1]*ann_size] = 1 # Anoto que hay objeto en este AB
    y[0,ann[0][1],ann[0][0], ann[1]*ann_size+1+clases_idx[ann[2][4]]] = 1 # Anoto la clase del objeto
    y[0,ann[0][1],ann[0][0], ann[1]*ann_size+1+cant_classes:ann[1]*ann_size+1+cant_classes+4] = coco_to_yolo(ann)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-445-5f9495cecca5> in <module>
#       3     y[0,ann[0][1],ann[0][0], ann[1]*ann_size] = 1 # Anoto que hay objeto en este AB
#       4     y[0,ann[0][1],ann[0][0], ann[1]*ann_size+1+clases_idx[ann[2][4]]] = 1 # Anoto la clase del objeto
# ----> 5     y[0,ann[0][1],ann[0][0], ann[1]*ann_size+1+cant_classes:ann[1]*ann_size+1+cant_classes+4] = coco_to_yolo(ann)
#
# NameError: name 'coco_to_yolo' is not defined

# %%
annotations[0]
# Out:
# (array([ 4, 13]),
#  3,
#  (0.0, 339.90722300000016, 288.24, 172.09277699999984, 'Tomato'))
